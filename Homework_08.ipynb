# %% [markdown]
# ## Homework 08: Classification
#
# ### Due: Midnight, March 22nd (with usual 2 hour grace period and late policy)
#
# ### Overview
#
# In this final homework before starting our course project, we will introduce the essential machine learning paradigm of **classification**. We will work with the **UCI Adult** dataset. This is a binary classification task.
#
# As we’ve discussed in this week’s lessons, the classification workflow is similar to what we’ve done for regression, with a few key differences:
# - We use `StratifiedKFold` instead of plain `KFold` so that every fold keeps the original class proportions.
# - We use classification metrics (e.g., accuracy, precision, recall, F1-score for binary classification) instead of regression metrics.
# - We could explore misclassified instances through a confusion matrix (though we will not do that in this homework).
#
# For this assignment, you’ll build a gradient boosting classification using `HistGradientBoostingClassifier` (HGBC) and explore ways of tuning the hyperparameters, including using the technique of early stopping, which basically avoiding have to tune the number of estimators (called `max_iter` in HGBC).
#
# HGBC has many advantages, which we explain below.
#
#
# ### Grading
#
# There are 7 graded problems, each worth 7 points, and you get 1 point free if you complete the assignment.

# %%
# General utilities
import os
import io
import time
import zipfile
import requests
from collections import Counter

# Data handling and visualization
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
from IPython.display import display
 
# Data source
from sklearn.datasets import fetch_openml

 
# scikit-learn core tools 
from sklearn.model_selection import (
    train_test_split,
    cross_val_score,
    StratifiedKFold,
    RandomizedSearchCV
)

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder

 
# Import model 
from sklearn.ensemble import HistGradientBoostingClassifier
 
# Metrics
from sklearn.metrics import balanced_accuracy_score, classification_report
 
# Distributions for random search
from scipy.stats import loguniform, randint, uniform

# pandas dtypes helpers
from pandas.api.types import is_numeric_dtype, is_categorical_dtype
from pandas import CategoricalDtype

# Optuna Hyperparameter Search tool    (may need to be installed)
import optuna


# Misc

random_seed = 42

def format_hms(seconds):
    return time.strftime("%H:%M:%S", time.gmtime(seconds))

# %% [markdown]
# ### Prelude 1: Load and Preprocess the UCI Adult Income Dataset
#
# - Load the dataset from sklearn
# - Preliminary EDA
# - Feature Engineering

# %%
# Load and clean
df = fetch_openml(name='adult', version=2, as_frame=True).frame

df.replace("?", np.nan, inplace=True)            # Some datasets use ? instead of Nan for missing data

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       46043 non-null  category
#  2   fnlwgt          48842 non-null  int64
#  3   education       48842 non-null  category
#  4   education-num   48842 non-null  int64
#  5   marital-status  48842 non-null  category
#  6   occupation      46033 non-null  category
#  7   relationship    48842 non-null  category
#  8   race            48842 non-null  category
#  9   sex             48842 non-null  category
#  10  capital-gain    48842 non-null  int64
#  11  capital-loss    48842 non-null  int64
#  12  hours-per-week  48842 non-null  int64
#  13  native-country  47985 non-null  category
#  14  class           48842 non-null  category
# dtypes: category(9), int64(6)
# memory usage: 2.7 MB

# %% [markdown]
# #### Check: Is the dataset imbalanced?

# %%
print(df['class'].value_counts(normalize=True))
# Out:
# class
# <=50K    0.760718
# >50K     0.239282
# Name: proportion, dtype: float64

# %% [markdown]
# **YES:** It looks like this dataset is somewhat imbalanced. Therefore, we will
# 1. Tell the model to compensate during training by setting `class_weight='balanced'` when defining the model;
# 2. Evaluate it `balanced_accuracy` instead of `accuracy` and with class-aware metrics (precision, recall, F1); and
# 3. [Optional] Adjust the probability threshold instead of relying on raw accuracy alone after examining the precision-recall trade-off you observe at 0.5.

# %% [markdown]
# ### Feature Engineering
#
# Based on the considerations in **Appendix One**, we'll make the following changes to the dataset to facilitate training:
#
#
# 1. Drop `fnlwgt` and `education`.
# 3. Replace `capital-gain` and `capital-loss` by their difference `capital_net` and add a log-scaled version `capital_net_log`.

# %%
# Drop the survey-weight column
df_eng = df.drop(columns=["fnlwgt"])

# Keep only the ordinal education feature
df_eng = df_eng.drop(columns=["education"])      # retain 'education-num'

# Combine capital gains and losses, add a log-scaled variant
df_eng["capital_net"]     = df_eng["capital-gain"] - df_eng["capital-loss"]
df_eng["capital_net_log"] = np.log1p(df_eng["capital_net"].clip(lower=0))
df_eng = df_eng.drop(columns=["capital-gain", "capital-loss"])

# check
df_eng.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        46043 non-null  category
#  2   education-num    48842 non-null  int64
#  3   marital-status   48842 non-null  category
#  4   occupation       46033 non-null  category
#  5   relationship     48842 non-null  category
#  6   race             48842 non-null  category
#  7   sex              48842 non-null  category
#  8   hours-per-week   48842 non-null  int64
#  9   native-country   47985 non-null  category
#  10  class            48842 non-null  category
#  11  capital_net      48842 non-null  int64
#  12  capital_net_log  48842 non-null  float64
# dtypes: category(8), float64(1), int64(4)
# memory usage: 2.2 MB

# %% [markdown]
# #### Separate target and split
#
# Create the feature set `X` and the target set `y` (using `class` as the target) and split the dataset into 80% training and 20% testing sets, making sure to stratify.

# %%
X = df_eng.drop(columns=["class"])
y = (df_eng["class"] == ">50K").astype(int)

# Split (with stratification)
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    random_state=random_seed,
    stratify=y                           # So same proportion of classes in train and test sets
)

print("Train:", X_train.shape, y_train.shape)
print("Test :", X_test.shape,  y_test.shape)
# Out:
# Train: (39073, 12) (39073,)
# Test : (9769, 12) (9769,)

# %% [markdown]
# ### Prelude 2: Create a data pipeline and the `HistGradientBoostingClassifier` model
#
# Histogram-based gradient boosting improves on the standard version by:
#
# * **Histogram splits:** bins each feature into ≤ `max_bins` quantiles (i.e., each bin is approximately the same size) and tests splits only between bins, slashing compute time and scaling to large data sets. Default for `max_bins` = 255.
# * **Native NaN handling:** treats missing values as their own bin—no imputation needed.
# * **Native Categorical Support**: accepts integer-encoded categories directly and tests “category c vs. all others” splits, eliminating one-hot blow-ups and fake orderings.
# * **Built-in early stopping:** stops training after no improvement in validation loss after `n_iter_no_change` rounds. `tol` defines "improvement" (default is 1e-7).
# * **Leaf shrinkage:** adds `l2_regularization`, which ridge-shrinks each leaf value (without changing tree shape) so tiny, noisy leaves have less effect.
#
# >**Summary:**  Histogram-based GB trades a tiny approximation error (binning) for a **huge speed-up** and adds extra conveniences, making it the preferred choice for large tabular data sets. Tuning workflow relies on **Early stopping** to stop training before overfitting occurs.

# %%
# Define a baseline model 

HGBC_model = HistGradientBoostingClassifier(
    # tree structure and learning rate
    learning_rate=0.1,            # These 5 parameters are at defaults for our baseline training in Problem 1             
    max_leaf_nodes=31,            # but will be tuned by randomized search in Problem 2 and Optuna in Problem 3               
    max_depth=None,               
    min_samples_leaf=20,          
    l2_regularization=0.0,        

    # bins and iteration
    max_bins=255,                 # default
    max_iter=500,                 # high enough for early stopping
    early_stopping=True,
    n_iter_no_change=20,
    validation_fraction=0.2,      # 20% monitored for early stopping
    tol=1e-7,                     # default tolerance for validation improvement

    # class imbalance
    class_weight="balanced",

    random_state=random_seed,
    verbose=0
)

# %% [markdown]
# ### Create a pipeline appropriate for HGBC
#
# **Why use a `Pipeline` instead of encoding in the dataset first?**
#
# * **Avoid data leakage.** In each CV fold, the `OrdinalEncoder` is refit only on that fold’s training data, so the validation split never influences the encoder.
# * **Single, reusable object.** The pipeline bundles preprocessing + model, letting you call `fit`/`predict` on raw data anywhere (CV, Optuna, production) with identical behavior.
# * **Compatible with search tools.** `cross_validate`, `GridSearchCV`, and Optuna expect an estimator that can be cloned and refit; a pipeline meets that requirement automatically.
#
# Put simply, the pipeline gives you leak-free evaluation and portable, hassle-free tuning without extra code.

# %%
enc = OrdinalEncoder(
    handle_unknown="use_encoded_value",   # Allow unseen categories during transform
    unknown_value=-1,                     # Code for unseen categories
    encoded_missing_value=-2,             # Code for missing values (NaN)
    dtype=np.int64                        # Needed for HistGradientBoostingClassifier
)

# Categorical features
cat_cols = X.select_dtypes(exclude=["number"]).columns.tolist()

# Numeric features (everything that isn’t object / category)
num_cols = X.select_dtypes(include=["number"]).columns.tolist()

preprocess = ColumnTransformer(
    [("cat", enc, cat_cols),
     ("num", "passthrough", num_cols)]
)

pipelined_model = Pipeline([
    ("prep", preprocess),
    ("gb",   HGBC_model)
])

# %% [markdown]
# ## Problem 1: Baseline Cross-Validation with F1
#
# In this problem, you will run a baseline cross-validation evaluation of your `HistGradientBoostingClassifier` pipeline, using `HGBC_model` defined above.
#
# **Background:**
#
# * Since the Adult dataset is imbalanced (about 24% positives, 76% negatives), accuracy alone is not reliable.
# * We will use the **F1 score** as the evaluation metric, since it balances precision (avoiding false positives) and recall (avoiding false negatives) in a single measure. This is a fairer metric for imbalanced classification, where both types of error matter.
# * We will apply **5-fold stratified cross-validation** to make sure each fold has the same proportion of the classes as the original dataset.
# * Repeated cross-validation is optional and not required here, because the Adult dataset is large and `HistGradientBoostingClassifier` is robust to small sampling differences.
#
# **Instructions:**
#
# 1. Set up a `StratifiedKFold` cross-validation object with 5 splits, shuffling enabled, and `random_state=random_seed`.
# 2. Use `cross_val_score` to estimate the mean F1 score and its standard deviation across the folds.
# 3. Print out the mean and standard deviation of the F1 score, rounded to 4 decimal places.
# 4. Answer the graded question.

# %%
# Your code here

# Stratified 5-fold CV
cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=random_seed
)

# Cross-validation with F1 scoring
cv_scores = cross_val_score(
    pipelined_model,
    X_train,
    y_train,
    cv=cv,
    scoring="f1",
    n_jobs=-1
)

# Print mean and std
print("F1 scores by fold:", np.round(cv_scores, 4))
print(f"Mean F1: {cv_scores.mean():.4f}")
print(f"Std F1 : {cv_scores.std():.4f}")
# Out:
# F1 scores by fold: [0.7176 0.7125 0.7131 0.7119 0.7065]
# Mean F1: 0.7123
# Std F1 : 0.0035

# %% [markdown]
# ### Problem 1 Graded Answer
#
# Set `a1` to the mean F1 score of the baseline model.

# %%
 # Your answer here

a1 = cv_scores.mean()                     # replace 0 with an expression

# %%
# DO NOT change this cell in any way

print(f'a1 = {a1:.4f}')
# Out:
# a1 = 0.7123

# %% [markdown]
# ## Problem 2: Hyperparameter Optimization with Randomized Search for F1
#
# In this problem, you will tune your `pipelined_model` using `RandomizedSearchCV` to identify the best combination of tree structure and learning rate parameters that maximize the **F1 score**.
#
# **Background:**
# The F1 score is our main metric because it balances precision and recall on an imbalanced dataset. Optimizing hyperparameters for F1 ensures we manage both false positives and false negatives in a single measure.
#
# **Instructions:**
#
# 1. Set up a randomized search over the following hyperparameter ranges, using appropriate random-number distributions:
#
#    * `learning_rate` (log-uniform between 1e-3 and 0.3)
#    * `max_leaf_nodes` (integer from 16 to 256)
#    * `max_depth` (integer from 2 to 10)
#    * `min_samples_leaf` (integer from 10 to 200)
#    * `l2_regularization` (uniform between 0.0 and 2.0)
# 2. Use **5-fold stratified cross-validation**, with the same settings as in Problem 1.
# 3. Start `n_iter` at 10 or 20 to prototype, but try for 50 - 100 trials. More trials will generally yield better results, if your time and machine allow.
# 4. After running the search, show a neatly formatted table of the top 5 results, using `display(...)` showing their mean F1 scores, standard deviation, and the chosen hyperparameter values.
# 5. Answer the graded question.

# %%
# Your code here


# Define parameter distributions
param_dist = {
    "gb__learning_rate": loguniform(1e-3, 0.3),
    "gb__max_leaf_nodes": randint(16, 256),
    "gb__max_depth": randint(2, 11),          # upper bound is exclusive
    "gb__min_samples_leaf": randint(10, 200),
    "gb__l2_regularization": uniform(0.0, 2.0)
}

# Stratified 5-fold CV (same as Problem 1)
cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=random_seed
)

# Randomized Search
random_search = RandomizedSearchCV(
    estimator=pipelined_model,
    param_distributions=param_dist,
    n_iter=100,  
    scoring="f1",
    cv=cv,
    random_state=random_seed,
    n_jobs=-1,
    verbose=1,
    return_train_score=False
)

# Fit search
random_search.fit(X_train, y_train)

# Convert results to DataFrame
results_df = pd.DataFrame(random_search.cv_results_)

# Select relevant columns
cols_to_display = [
    "mean_test_score",
    "std_test_score",
    "param_gb__learning_rate",
    "param_gb__max_leaf_nodes",
    "param_gb__max_depth",
    "param_gb__min_samples_leaf",
    "param_gb__l2_regularization"
]

# Sort by best F1 score
top_results = (
    results_df[cols_to_display]
    .sort_values(by="mean_test_score", ascending=False)
    .head(5)
)

# Display nicely
display(top_results)

# Print best score and params
print("\nBest F1 score:", round(random_search.best_score_, 4))
print("Best parameters:", random_search.best_params_)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
#     mean_test_score  std_test_score  param_gb__learning_rate  \
# 19         0.712000        0.003063                 0.127541
# 60         0.711962        0.004237                 0.268164
# 21         0.711405        0.003213                 0.157664
# 59         0.711045        0.003477                 0.229549
# 14         0.711026        0.002790                 0.070991
#
#     param_gb__max_leaf_nodes  param_gb__max_depth  param_gb__min_samples_leaf  \
# 19                        48                    3                          57
# 60                       206                    5                         169
# 21                       242                    2                         110
# 59                        61                    2                         190
# 14                        39                    6                         163
#
#     param_gb__l2_regularization
# 19                     1.829919
# 60                     1.144585
# 21                     1.275115
# 59                     1.495438
# 14                     1.689068
# Best F1 score: 0.712
# Best parameters: {'gb__l2_regularization': np.float64(1.8299193510875615), 'gb__learning_rate': np.float64(0.12754065069696732), 'gb__max_depth': 3, 'gb__max_leaf_nodes': 48, 'gb__min_samples_leaf': 57}

# %% [markdown]
# ### Problem 2 Graded Answer
#
# Set `a2` to the mean F1 score of the best model found.

# %%
 # Your answer here

a2 = random_search.best_score_                    # replace 0 with your answer, may copy from the displayed results

# %%
# DO NOT change this cell in any way

print(f'a2 = {a2:.4f}')
# Out:
# a2 = 0.7120

# %% [markdown]
# ## Problem 3: Hyperparameter Optimization with Optuna for F1
#
# In this problem, you will explore **Optuna**, a powerful hyperparameter optimization framework, to identify the best combination of hyperparameters that maximize the F1 score of your `pipelined_model`.
#
# **Background:**
# Optuna uses a smarter sampling strategy than grid search or randomized search, allowing you to explore the hyperparameter space more efficiently. It also supports *pruning*, which can stop unpromising trials early to save time. This makes it a popular SOTA optimization tool.
#
# **Before you start** browse the [Optuna documentation](https://optuna.org) and view the [tutorial video](https://optuna.readthedocs.io/en/stable/tutorial/index.html).
#
# As before, we focus on the **F1 score** because it balances precision and recall, making it more robust on an imbalanced dataset.
#
# **Instructions:**
#
# 1. Define an Optuna objective function to optimize F1 score, sampling the exact same hyperparameter ranges you did in Problem 2 and using the same CV settings.
# 3. Set up an Optuna study with a reasonable number of trials (e.g., up to 100 depending on runtime resources--on my machine Optuna runs about 10x faster than randomized search for the same number of trials, but YMMV).
# 4. After running the optimization, `display` a clean table with the top 5 trials showing their F1 scores and corresponding hyperparameter settings.
# 5. Answer the graded question.
#
# **Note:**  There are many resources on Optuna you can find on the web, but for this problem, you have my permission to let ChatGPT write the code for you.

# %%
# Your code here

from sklearn.base import clone

# Same CV settings as before
cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=random_seed
)

def objective(trial):
    # Sample hyperparameters from the same ranges as Problem 2
    params = {
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.3, log=True),
        "max_leaf_nodes": trial.suggest_int("max_leaf_nodes", 16, 255),
        "max_depth": trial.suggest_int("max_depth", 2, 10),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 10, 199),
        "l2_regularization": trial.suggest_float("l2_regularization", 0.0, 2.0)
    }

    # Clone pipeline so each trial is independent
    model = clone(pipelined_model)
    model.set_params(
        gb__learning_rate=params["learning_rate"],
        gb__max_leaf_nodes=params["max_leaf_nodes"],
        gb__max_depth=params["max_depth"],
        gb__min_samples_leaf=params["min_samples_leaf"],
        gb__l2_regularization=params["l2_regularization"]
    )

    scores = cross_val_score(
        model,
        X_train,
        y_train,
        cv=cv,
        scoring="f1",
        n_jobs=-1
    )

    return scores.mean()

# Create and run study
study = optuna.create_study(direction="maximize", study_name="hgbc_f1_optuna")
study.optimize(objective, n_trials=100, show_progress_bar=True)

# Best result
print("Best F1 score:", round(study.best_value, 4))
print("Best parameters:", study.best_params)

# Build a clean top-5 table
trials_df = study.trials_dataframe()

top5 = (
    trials_df.loc[:, [
        "number",
        "value",
        "params_learning_rate",
        "params_max_leaf_nodes",
        "params_max_depth",
        "params_min_samples_leaf",
        "params_l2_regularization"
    ]]
    .sort_values("value", ascending=False)
    .head(5)
    .rename(columns={
        "number": "trial",
        "value": "mean_f1",
        "params_learning_rate": "learning_rate",
        "params_max_leaf_nodes": "max_leaf_nodes",
        "params_max_depth": "max_depth",
        "params_min_samples_leaf": "min_samples_leaf",
        "params_l2_regularization": "l2_regularization"
    })
)

display(top5)
# Out:
# [I 2026-03-22 14:24:17,793] A new study created in memory with name: hgbc_f1_optuna
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2026-03-22 14:24:21,337] Trial 0 finished with value: 0.6671583252058902 and parameters: {'learning_rate': 0.002447527188000613, 'max_leaf_nodes': 25, 'max_depth': 6, 'min_samples_leaf': 175, 'l2_regularization': 1.5917864313552161}. Best is trial 0 with value: 0.6671583252058902.
# [I 2026-03-22 14:24:24,580] Trial 1 finished with value: 0.7100778507135257 and parameters: {'learning_rate': 0.0385506113891386, 'max_leaf_nodes': 82, 'max_depth': 9, 'min_samples_leaf': 168, 'l2_regularization': 1.1746404890598592}. Best is trial 1 with value: 0.7100778507135257.
# [I 2026-03-22 14:24:27,484] Trial 2 finished with value: 0.7104370539761934 and parameters: {'learning_rate': 0.053228300460175716, 'max_leaf_nodes': 151, 'max_depth': 8, 'min_samples_leaf': 82, 'l2_regularization': 1.8680913306279252}. Best is trial 2 with value: 0.7104370539761934.
# [I 2026-03-22 14:24:29,082] Trial 3 finished with value: 0.7088467091550061 and parameters: {'learning_rate': 0.2947581143975352, 'max_leaf_nodes': 121, 'max_depth': 9, 'min_samples_leaf': 193, 'l2_regularization': 0.13056556115894202}. Best is trial 2 with value: 0.7104370539761934.
# [I 2026-03-22 14:24:33,113] Trial 4 finished with value: 0.669453922007345 and parameters: {'learning_rate': 0.0010885957297993062, 'max_leaf_nodes': 207, 'max_depth': 9, 'min_samples_leaf': 96, 'l2_regularization': 0.3296818119481726}. Best is trial 2 with value: 0.7104370539761934.
# [I 2026-03-22 14:24:35,456] Trial 5 finished with value: 0.708742305921377 and parameters: {'learning_rate': 0.06568317300913608, 'max_leaf_nodes': 55, 'max_depth': 3, 'min_samples_leaf': 127, 'l2_regularization': 1.7029675363918235}. Best is trial 2 with value: 0.7104370539761934.
# [I 2026-03-22 14:24:37,965] Trial 6 finished with value: 0.6971273706986995 and parameters: {'learning_rate': 0.017199850616936595, 'max_leaf_nodes': 100, 'max_depth': 4, 'min_samples_leaf': 107, 'l2_regularization': 1.2771473170258154}. Best is trial 2 with value: 0.7104370539761934.
# [I 2026-03-22 14:24:39,130] Trial 7 finished with value: 0.6169364787278694 and parameters: {'learning_rate': 0.0020687797750078172, 'max_leaf_nodes': 112, 'max_depth': 2, 'min_samples_leaf': 62, 'l2_regularization': 0.5611250237111034}. Best is trial 2 with value: 0.7104370539761934.
# [I 2026-03-22 14:24:40,076] Trial 8 finished with value: 0.7104040126287419 and parameters: {'learning_rate': 0.09949187483431199, 'max_leaf_nodes': 175, 'max_depth': 10, 'min_samples_leaf': 90, 'l2_regularization': 1.5501353352525964}. Best is trial 2 with value: 0.7104370539761934.
# [I 2026-03-22 14:24:41,668] Trial 9 finished with value: 0.6588795977549807 and parameters: {'learning_rate': 0.002959971606470027, 'max_leaf_nodes': 24, 'max_depth': 4, 'min_samples_leaf': 56, 'l2_regularization': 0.0751841982829613}. Best is trial 2 with value: 0.7104370539761934.
# [I 2026-03-22 14:24:44,078] Trial 10 finished with value: 0.7075450563910884 and parameters: {'learning_rate': 0.011629909719353232, 'max_leaf_nodes': 247, 'max_depth': 7, 'min_samples_leaf': 11, 'l2_regularization': 1.9968857766533397}. Best is trial 2 with value: 0.7104370539761934.
# [I 2026-03-22 14:24:44,867] Trial 11 finished with value: 0.7100388079833175 and parameters: {'learning_rate': 0.14526611904212353, 'max_leaf_nodes': 179, 'max_depth': 7, 'min_samples_leaf': 66, 'l2_regularization': 1.9154126589305231}. Best is trial 2 with value: 0.7104370539761934.
# [I 2026-03-22 14:24:46,317] Trial 12 finished with value: 0.7095024002652127 and parameters: {'learning_rate': 0.06266484602598923, 'max_leaf_nodes': 165, 'max_depth': 10, 'min_samples_leaf': 131, 'l2_regularization': 1.4052996681170706}. Best is trial 2 with value: 0.7104370539761934.
# [I 2026-03-22 14:24:46,921] Trial 13 finished with value: 0.7096314632556535 and parameters: {'learning_rate': 0.1336885870323919, 'max_leaf_nodes': 165, 'max_depth': 10, 'min_samples_leaf': 23, 'l2_regularization': 0.7711621057617895}. Best is trial 2 with value: 0.7104370539761934.
# [I 2026-03-22 14:24:48,914] Trial 14 finished with value: 0.7089713061836689 and parameters: {'learning_rate': 0.02964962189567787, 'max_leaf_nodes': 214, 'max_depth': 7, 'min_samples_leaf': 94, 'l2_regularization': 0.933280196991322}. Best is trial 2 with value: 0.7104370539761934.
# [I 2026-03-22 14:24:51,526] Trial 15 finished with value: 0.6970234200526446 and parameters: {'learning_rate': 0.00795889651361023, 'max_leaf_nodes': 144, 'max_depth': 8, 'min_samples_leaf': 40, 'l2_regularization': 1.6815905628125098}. Best is trial 2 with value: 0.7104370539761934.
# [I 2026-03-22 14:24:52,458] Trial 16 finished with value: 0.7109682959318516 and parameters: {'learning_rate': 0.12286703340157473, 'max_leaf_nodes': 201, 'max_depth': 6, 'min_samples_leaf': 86, 'l2_regularization': 1.4698938852692973}. Best is trial 16 with value: 0.7109682959318516.
# [I 2026-03-22 14:24:54,142] Trial 17 finished with value: 0.7069278795223733 and parameters: {'learning_rate': 0.03106644333301229, 'max_leaf_nodes': 212, 'max_depth': 5, 'min_samples_leaf': 128, 'l2_regularization': 1.0865037703552212}. Best is trial 16 with value: 0.7109682959318516.
# [I 2026-03-22 14:24:54,609] Trial 18 finished with value: 0.7093340862203831 and parameters: {'learning_rate': 0.29218877677797467, 'max_leaf_nodes': 253, 'max_depth': 6, 'min_samples_leaf': 75, 'l2_regularization': 1.8724939639067584}. Best is trial 16 with value: 0.7109682959318516.
# [I 2026-03-22 14:24:56,695] Trial 19 finished with value: 0.6867877993935406 and parameters: {'learning_rate': 0.00645711601009917, 'max_leaf_nodes': 142, 'max_depth': 6, 'min_samples_leaf': 41, 'l2_regularization': 1.4259793027055947}. Best is trial 16 with value: 0.7109682959318516.
# [I 2026-03-22 14:24:58,246] Trial 20 finished with value: 0.7101730739585765 and parameters: {'learning_rate': 0.07011356784402004, 'max_leaf_nodes': 195, 'max_depth': 8, 'min_samples_leaf': 149, 'l2_regularization': 1.7683273014241658}. Best is trial 16 with value: 0.7109682959318516.
# [I 2026-03-22 14:24:58,963] Trial 21 finished with value: 0.7093608691017341 and parameters: {'learning_rate': 0.14417681805270807, 'max_leaf_nodes': 175, 'max_depth': 8, 'min_samples_leaf': 86, 'l2_regularization': 1.4842035631414787}. Best is trial 16 with value: 0.7109682959318516.
# [I 2026-03-22 14:24:59,946] Trial 22 finished with value: 0.7102989643344726 and parameters: {'learning_rate': 0.09966335653099342, 'max_leaf_nodes': 229, 'max_depth': 10, 'min_samples_leaf': 113, 'l2_regularization': 1.303508581629678}. Best is trial 16 with value: 0.7109682959318516.
# [I 2026-03-22 14:25:01,600] Trial 23 finished with value: 0.710270958075696 and parameters: {'learning_rate': 0.04429433935434493, 'max_leaf_nodes': 191, 'max_depth': 5, 'min_samples_leaf': 82, 'l2_regularization': 1.5900147963615407}. Best is trial 16 with value: 0.7109682959318516.
# [I 2026-03-22 14:25:02,294] Trial 24 finished with value: 0.7091287358474709 and parameters: {'learning_rate': 0.17886438615382327, 'max_leaf_nodes': 153, 'max_depth': 9, 'min_samples_leaf': 112, 'l2_regularization': 1.778138613268427}. Best is trial 16 with value: 0.7109682959318516.
# [I 2026-03-22 14:25:04,647] Trial 25 finished with value: 0.7090278128723506 and parameters: {'learning_rate': 0.020257554609248513, 'max_leaf_nodes': 226, 'max_depth': 8, 'min_samples_leaf': 45, 'l2_regularization': 0.9569035495846208}. Best is trial 16 with value: 0.7109682959318516.
# [I 2026-03-22 14:25:05,816] Trial 26 finished with value: 0.7111629323699208 and parameters: {'learning_rate': 0.09766632158547266, 'max_leaf_nodes': 126, 'max_depth': 7, 'min_samples_leaf': 74, 'l2_regularization': 1.5556183267174635}. Best is trial 26 with value: 0.7111629323699208.
# [I 2026-03-22 14:25:07,019] Trial 27 finished with value: 0.710901992822226 and parameters: {'learning_rate': 0.08871160160198614, 'max_leaf_nodes': 88, 'max_depth': 7, 'min_samples_leaf': 73, 'l2_regularization': 1.3220713273068123}. Best is trial 26 with value: 0.7111629323699208.
# [I 2026-03-22 14:25:07,614] Trial 28 finished with value: 0.710213964276624 and parameters: {'learning_rate': 0.2110457891267489, 'max_leaf_nodes': 73, 'max_depth': 5, 'min_samples_leaf': 68, 'l2_regularization': 1.2584147397237349}. Best is trial 26 with value: 0.7111629323699208.
# [I 2026-03-22 14:25:08,609] Trial 29 finished with value: 0.7105839976399804 and parameters: {'learning_rate': 0.07703770220862893, 'max_leaf_nodes': 125, 'max_depth': 6, 'min_samples_leaf': 24, 'l2_regularization': 1.3987533139732848}. Best is trial 26 with value: 0.7111629323699208.
# [I 2026-03-22 14:25:09,417] Trial 30 finished with value: 0.7103574169130585 and parameters: {'learning_rate': 0.1068205734739598, 'max_leaf_nodes': 51, 'max_depth': 7, 'min_samples_leaf': 52, 'l2_regularization': 0.8236517025522307}. Best is trial 26 with value: 0.7111629323699208.
# [I 2026-03-22 14:25:10,380] Trial 31 finished with value: 0.71062998401607 and parameters: {'learning_rate': 0.08643274973180277, 'max_leaf_nodes': 124, 'max_depth': 6, 'min_samples_leaf': 29, 'l2_regularization': 1.1506881790271266}. Best is trial 26 with value: 0.7111629323699208.
# [I 2026-03-22 14:25:10,870] Trial 32 finished with value: 0.7095384825442839 and parameters: {'learning_rate': 0.21648426298038526, 'max_leaf_nodes': 95, 'max_depth': 6, 'min_samples_leaf': 29, 'l2_regularization': 1.1809036849662617}. Best is trial 26 with value: 0.7111629323699208.
# [I 2026-03-22 14:25:12,787] Trial 33 finished with value: 0.7094373439124485 and parameters: {'learning_rate': 0.040569303647436425, 'max_leaf_nodes': 77, 'max_depth': 7, 'min_samples_leaf': 74, 'l2_regularization': 1.147475335786058}. Best is trial 26 with value: 0.7111629323699208.
# [I 2026-03-22 14:25:14,257] Trial 34 finished with value: 0.7127704154571952 and parameters: {'learning_rate': 0.08905948282237294, 'max_leaf_nodes': 130, 'max_depth': 5, 'min_samples_leaf': 98, 'l2_regularization': 1.077887350272901}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:15,853] Trial 35 finished with value: 0.7107158885274801 and parameters: {'learning_rate': 0.054505980809393055, 'max_leaf_nodes': 104, 'max_depth': 5, 'min_samples_leaf': 102, 'l2_regularization': 0.650493751149898}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:17,379] Trial 36 finished with value: 0.7031244486915504 and parameters: {'learning_rate': 0.026230820292746176, 'max_leaf_nodes': 132, 'max_depth': 4, 'min_samples_leaf': 121, 'l2_regularization': 1.5316051804934536}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:18,725] Trial 37 finished with value: 0.7110309632490173 and parameters: {'learning_rate': 0.1254529496720532, 'max_leaf_nodes': 56, 'max_depth': 5, 'min_samples_leaf': 168, 'l2_regularization': 1.0514046459517086}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:19,493] Trial 38 finished with value: 0.7118364886566247 and parameters: {'learning_rate': 0.2847988775079597, 'max_leaf_nodes': 57, 'max_depth': 3, 'min_samples_leaf': 179, 'l2_regularization': 1.0207953974407198}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:20,589] Trial 39 finished with value: 0.7120449030890057 and parameters: {'learning_rate': 0.26839606503010244, 'max_leaf_nodes': 45, 'max_depth': 2, 'min_samples_leaf': 189, 'l2_regularization': 0.49881143135143824}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:21,679] Trial 40 finished with value: 0.7118329247498776 and parameters: {'learning_rate': 0.2765212196238335, 'max_leaf_nodes': 43, 'max_depth': 2, 'min_samples_leaf': 182, 'l2_regularization': 0.47149802291654336}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:22,840] Trial 41 finished with value: 0.7109756913718894 and parameters: {'learning_rate': 0.2677020420579182, 'max_leaf_nodes': 44, 'max_depth': 2, 'min_samples_leaf': 199, 'l2_regularization': 0.3568656169464795}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:23,968] Trial 42 finished with value: 0.7112952701256311 and parameters: {'learning_rate': 0.1969898450433503, 'max_leaf_nodes': 36, 'max_depth': 3, 'min_samples_leaf': 182, 'l2_regularization': 0.3987959239495271}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:25,108] Trial 43 finished with value: 0.7125017493519061 and parameters: {'learning_rate': 0.1905683118238966, 'max_leaf_nodes': 36, 'max_depth': 3, 'min_samples_leaf': 179, 'l2_regularization': 0.36147186123829544}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:25,988] Trial 44 finished with value: 0.7111379532335236 and parameters: {'learning_rate': 0.2480604578975342, 'max_leaf_nodes': 19, 'max_depth': 3, 'min_samples_leaf': 150, 'l2_regularization': 0.21444112050544353}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:27,165] Trial 45 finished with value: 0.7116680762868347 and parameters: {'learning_rate': 0.1748606895087483, 'max_leaf_nodes': 66, 'max_depth': 2, 'min_samples_leaf': 189, 'l2_regularization': 0.5460707306225324}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:27,943] Trial 46 finished with value: 0.7095292846283995 and parameters: {'learning_rate': 0.29936286653330274, 'max_leaf_nodes': 34, 'max_depth': 3, 'min_samples_leaf': 155, 'l2_regularization': 0.4732283023053324}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:29,074] Trial 47 finished with value: 0.7112317515346913 and parameters: {'learning_rate': 0.1652155083401993, 'max_leaf_nodes': 66, 'max_depth': 2, 'min_samples_leaf': 175, 'l2_regularization': 0.2519185337911749}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:29,922] Trial 48 finished with value: 0.7118949298640733 and parameters: {'learning_rate': 0.22605416387757907, 'max_leaf_nodes': 32, 'max_depth': 3, 'min_samples_leaf': 161, 'l2_regularization': 0.702781071038294}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:30,767] Trial 49 finished with value: 0.7111905995981672 and parameters: {'learning_rate': 0.22622087193216356, 'max_leaf_nodes': 28, 'max_depth': 4, 'min_samples_leaf': 159, 'l2_regularization': 0.7150502676277123}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:31,738] Trial 50 finished with value: 0.7120253768314917 and parameters: {'learning_rate': 0.1614652870041696, 'max_leaf_nodes': 16, 'max_depth': 4, 'min_samples_leaf': 137, 'l2_regularization': 0.8960757564095432}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:32,891] Trial 51 finished with value: 0.7112290198664001 and parameters: {'learning_rate': 0.14135192179274048, 'max_leaf_nodes': 18, 'max_depth': 4, 'min_samples_leaf': 136, 'l2_regularization': 0.863015652058247}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:34,009] Trial 52 finished with value: 0.712608094836178 and parameters: {'learning_rate': 0.17818892104414374, 'max_leaf_nodes': 30, 'max_depth': 3, 'min_samples_leaf': 140, 'l2_regularization': 0.648118278365678}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:35,039] Trial 53 finished with value: 0.7116440699330348 and parameters: {'learning_rate': 0.1683977915021064, 'max_leaf_nodes': 27, 'max_depth': 3, 'min_samples_leaf': 143, 'l2_regularization': 0.6245154600330594}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:36,275] Trial 54 finished with value: 0.7112588611617486 and parameters: {'learning_rate': 0.12672023730508186, 'max_leaf_nodes': 33, 'max_depth': 4, 'min_samples_leaf': 170, 'l2_regularization': 0.7597030929150685}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:37,676] Trial 55 finished with value: 0.6288986681166572 and parameters: {'learning_rate': 0.0012470707387589736, 'max_leaf_nodes': 44, 'max_depth': 3, 'min_samples_leaf': 190, 'l2_regularization': 0.03825978816094183}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:38,530] Trial 56 finished with value: 0.7120463103016138 and parameters: {'learning_rate': 0.22053045046315334, 'max_leaf_nodes': 17, 'max_depth': 4, 'min_samples_leaf': 161, 'l2_regularization': 0.8514823636305066}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:40,115] Trial 57 finished with value: 0.6660768807159505 and parameters: {'learning_rate': 0.004233545442892923, 'max_leaf_nodes': 20, 'max_depth': 4, 'min_samples_leaf': 137, 'l2_regularization': 0.8422673433593075}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:41,598] Trial 58 finished with value: 0.7116532336608417 and parameters: {'learning_rate': 0.11338210068215646, 'max_leaf_nodes': 16, 'max_depth': 4, 'min_samples_leaf': 167, 'l2_regularization': 0.5458694793015019}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:42,873] Trial 59 finished with value: 0.7116758648348325 and parameters: {'learning_rate': 0.16852454160767774, 'max_leaf_nodes': 41, 'max_depth': 2, 'min_samples_leaf': 120, 'l2_regularization': 0.922034486009925}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:44,280] Trial 60 finished with value: 0.7091515889961398 and parameters: {'learning_rate': 0.06243759399514357, 'max_leaf_nodes': 60, 'max_depth': 3, 'min_samples_leaf': 141, 'l2_regularization': 0.13534933413591263}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:45,245] Trial 61 finished with value: 0.7120711051433071 and parameters: {'learning_rate': 0.23765516258349523, 'max_leaf_nodes': 29, 'max_depth': 3, 'min_samples_leaf': 149, 'l2_regularization': 0.6900392688526459}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:46,065] Trial 62 finished with value: 0.7119347612220415 and parameters: {'learning_rate': 0.19477620474109295, 'max_leaf_nodes': 48, 'max_depth': 5, 'min_samples_leaf': 148, 'l2_regularization': 0.5977868151266588}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:47,217] Trial 63 finished with value: 0.7118697358735804 and parameters: {'learning_rate': 0.1500321425019694, 'max_leaf_nodes': 24, 'max_depth': 4, 'min_samples_leaf': 164, 'l2_regularization': 0.4513073289328309}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:48,178] Trial 64 finished with value: 0.7117157863902979 and parameters: {'learning_rate': 0.23229328297538185, 'max_leaf_nodes': 36, 'max_depth': 3, 'min_samples_leaf': 101, 'l2_regularization': 0.274281440221111}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:49,395] Trial 65 finished with value: 0.7117833446894213 and parameters: {'learning_rate': 0.1920899601046106, 'max_leaf_nodes': 111, 'max_depth': 2, 'min_samples_leaf': 174, 'l2_regularization': 0.9089957689596745}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:51,092] Trial 66 finished with value: 0.6865123913370429 and parameters: {'learning_rate': 0.012800086818267572, 'max_leaf_nodes': 24, 'max_depth': 4, 'min_samples_leaf': 198, 'l2_regularization': 0.7312336440001759}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:52,217] Trial 67 finished with value: 0.7115366313892394 and parameters: {'learning_rate': 0.13851066230681403, 'max_leaf_nodes': 66, 'max_depth': 5, 'min_samples_leaf': 156, 'l2_regularization': 0.7932696162279884}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:53,443] Trial 68 finished with value: 0.7061946155125776 and parameters: {'learning_rate': 0.087656968224467, 'max_leaf_nodes': 86, 'max_depth': 2, 'min_samples_leaf': 122, 'l2_regularization': 0.5103426180403049}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:54,845] Trial 69 finished with value: 0.7111629986467223 and parameters: {'learning_rate': 0.11496195299075788, 'max_leaf_nodes': 51, 'max_depth': 3, 'min_samples_leaf': 133, 'l2_regularization': 0.9813794656018157}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:55,879] Trial 70 finished with value: 0.7109807953356849 and parameters: {'learning_rate': 0.2314658893770064, 'max_leaf_nodes': 16, 'max_depth': 3, 'min_samples_leaf': 108, 'l2_regularization': 0.663468108109009}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:56,677] Trial 71 finished with value: 0.7102020504820039 and parameters: {'learning_rate': 0.1805056071407614, 'max_leaf_nodes': 50, 'max_depth': 5, 'min_samples_leaf': 146, 'l2_regularization': 0.6078547302234628}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:57,534] Trial 72 finished with value: 0.7107007391207867 and parameters: {'learning_rate': 0.19742553147297448, 'max_leaf_nodes': 39, 'max_depth': 5, 'min_samples_leaf': 154, 'l2_regularization': 0.41044996457322735}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:58,577] Trial 73 finished with value: 0.7111304044848261 and parameters: {'learning_rate': 0.15177264598927762, 'max_leaf_nodes': 48, 'max_depth': 4, 'min_samples_leaf': 126, 'l2_regularization': 0.5689412963717697}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:25:59,299] Trial 74 finished with value: 0.7100361027702309 and parameters: {'learning_rate': 0.24900226203862358, 'max_leaf_nodes': 29, 'max_depth': 5, 'min_samples_leaf': 151, 'l2_regularization': 0.8933650367592169}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:26:00,761] Trial 75 finished with value: 0.7109620652596097 and parameters: {'learning_rate': 0.10456594316893594, 'max_leaf_nodes': 24, 'max_depth': 4, 'min_samples_leaf': 141, 'l2_regularization': 0.7985460406176813}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:26:02,447] Trial 76 finished with value: 0.7114508555767536 and parameters: {'learning_rate': 0.07340106960248895, 'max_leaf_nodes': 61, 'max_depth': 5, 'min_samples_leaf': 184, 'l2_regularization': 1.0931813376830646}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:26:03,146] Trial 77 finished with value: 0.7087459930731912 and parameters: {'learning_rate': 0.2979697234928413, 'max_leaf_nodes': 153, 'max_depth': 4, 'min_samples_leaf': 93, 'l2_regularization': 0.33334541903379655}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:26:04,445] Trial 78 finished with value: 0.7118312237688902 and parameters: {'learning_rate': 0.20188559863503824, 'max_leaf_nodes': 77, 'max_depth': 3, 'min_samples_leaf': 163, 'l2_regularization': 0.6708724065308128}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:26:05,664] Trial 79 finished with value: 0.711043346329799 and parameters: {'learning_rate': 0.15493861451890495, 'max_leaf_nodes': 38, 'max_depth': 2, 'min_samples_leaf': 173, 'l2_regularization': 0.6144799582673444}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:26:06,282] Trial 80 finished with value: 0.7103586976293592 and parameters: {'learning_rate': 0.2584239417567014, 'max_leaf_nodes': 46, 'max_depth': 4, 'min_samples_leaf': 113, 'l2_regularization': 0.9849413052166855}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:26:07,245] Trial 81 finished with value: 0.7115270620395171 and parameters: {'learning_rate': 0.21257277717062786, 'max_leaf_nodes': 31, 'max_depth': 3, 'min_samples_leaf': 161, 'l2_regularization': 0.7228427615579873}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:26:08,361] Trial 82 finished with value: 0.7126051257802183 and parameters: {'learning_rate': 0.24034686756926338, 'max_leaf_nodes': 31, 'max_depth': 3, 'min_samples_leaf': 147, 'l2_regularization': 0.5117234019557166}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:26:09,592] Trial 83 finished with value: 0.7099462182370491 and parameters: {'learning_rate': 0.12611519684411365, 'max_leaf_nodes': 22, 'max_depth': 2, 'min_samples_leaf': 146, 'l2_regularization': 0.3868104743217722}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:26:10,632] Trial 84 finished with value: 0.7109269171209079 and parameters: {'learning_rate': 0.2547791454113495, 'max_leaf_nodes': 29, 'max_depth': 3, 'min_samples_leaf': 187, 'l2_regularization': 0.5128030176097917}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:26:11,402] Trial 85 finished with value: 0.7101997494949652 and parameters: {'learning_rate': 0.18778943095320882, 'max_leaf_nodes': 38, 'max_depth': 6, 'min_samples_leaf': 130, 'l2_regularization': 0.5760397388196368}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:26:12,599] Trial 86 finished with value: 0.7112417085209135 and parameters: {'learning_rate': 0.1640346929686975, 'max_leaf_nodes': 57, 'max_depth': 3, 'min_samples_leaf': 153, 'l2_regularization': 0.43632349404994497}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:26:13,816] Trial 87 finished with value: 0.711678550555314 and parameters: {'learning_rate': 0.209289724291299, 'max_leaf_nodes': 50, 'max_depth': 2, 'min_samples_leaf': 194, 'l2_regularization': 1.2198410852664279}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:26:15,284] Trial 88 finished with value: 0.7109990386667489 and parameters: {'learning_rate': 0.12916333040604022, 'max_leaf_nodes': 237, 'max_depth': 4, 'min_samples_leaf': 180, 'l2_regularization': 0.508014615140156}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:26:15,899] Trial 89 finished with value: 0.7108184451232669 and parameters: {'learning_rate': 0.26335221874637427, 'max_leaf_nodes': 16, 'max_depth': 5, 'min_samples_leaf': 138, 'l2_regularization': 1.0643835200954914}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:26:16,781] Trial 90 finished with value: 0.7105377063799643 and parameters: {'learning_rate': 0.29511521380022965, 'max_leaf_nodes': 31, 'max_depth': 3, 'min_samples_leaf': 157, 'l2_regularization': 0.849592424932538}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:26:17,793] Trial 91 finished with value: 0.7107988710011774 and parameters: {'learning_rate': 0.2111419578748361, 'max_leaf_nodes': 33, 'max_depth': 3, 'min_samples_leaf': 167, 'l2_regularization': 0.7025312332773298}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:26:18,764] Trial 92 finished with value: 0.7115412890749523 and parameters: {'learning_rate': 0.2347961617968785, 'max_leaf_nodes': 43, 'max_depth': 3, 'min_samples_leaf': 147, 'l2_regularization': 0.7682696050767556}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:26:19,777] Trial 93 finished with value: 0.7106836140925622 and parameters: {'learning_rate': 0.18072957073305881, 'max_leaf_nodes': 25, 'max_depth': 4, 'min_samples_leaf': 163, 'l2_regularization': 0.664694221741894}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:26:20,996] Trial 94 finished with value: 0.7069397833147011 and parameters: {'learning_rate': 0.09601499774102774, 'max_leaf_nodes': 41, 'max_depth': 2, 'min_samples_leaf': 172, 'l2_regularization': 0.5783689769243693}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:26:22,173] Trial 95 finished with value: 0.710896463349176 and parameters: {'learning_rate': 0.15628466706535757, 'max_leaf_nodes': 185, 'max_depth': 3, 'min_samples_leaf': 133, 'l2_regularization': 0.295911817304242}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:26:23,127] Trial 96 finished with value: 0.7103475108651425 and parameters: {'learning_rate': 0.2318247014177892, 'max_leaf_nodes': 159, 'max_depth': 3, 'min_samples_leaf': 178, 'l2_regularization': 0.9463146508185567}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:26:24,284] Trial 97 finished with value: 0.710736192581974 and parameters: {'learning_rate': 0.14596456370282385, 'max_leaf_nodes': 21, 'max_depth': 4, 'min_samples_leaf': 150, 'l2_regularization': 0.1908337383351188}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:26:25,542] Trial 98 finished with value: 0.7120481588173347 and parameters: {'learning_rate': 0.1846636712574566, 'max_leaf_nodes': 70, 'max_depth': 2, 'min_samples_leaf': 144, 'l2_regularization': 0.8753802965550502}. Best is trial 34 with value: 0.7127704154571952.
# [I 2026-03-22 14:26:26,782] Trial 99 finished with value: 0.7092791134445702 and parameters: {'learning_rate': 0.109860527936642, 'max_leaf_nodes': 98, 'max_depth': 2, 'min_samples_leaf': 143, 'l2_regularization': 1.0146048421926603}. Best is trial 34 with value: 0.7127704154571952.
# Best F1 score: 0.7128
# Best parameters: {'learning_rate': 0.08905948282237294, 'max_leaf_nodes': 130, 'max_depth': 5, 'min_samples_leaf': 98, 'l2_regularization': 1.077887350272901}
#     trial   mean_f1  learning_rate  max_leaf_nodes  max_depth  \
# 34     34  0.712770       0.089059             130          5
# 52     52  0.712608       0.178189              30          3
# 82     82  0.712605       0.240347              31          3
# 43     43  0.712502       0.190568              36          3
# 61     61  0.712071       0.237655              29          3
#
#     min_samples_leaf  l2_regularization
# 34                98           1.077887
# 52               140           0.648118
# 82               147           0.511723
# 43               179           0.361472
# 61               149           0.690039

# %% [markdown]
# ### Problem 3 Graded Answer
#
# Set `a3` to the mean F1 score of the best model found.

# %%
 # Your answer here

a3 = study.best_value                    # replace 0 with your answer, may copy from the displayed results

# %%
# DO NOT change this cell in any way

print(f'a3 = {a3:.4f}')
# Out:
# a3 = 0.7128

# %% [markdown]
# ## Problem 4: Final Model Evaluation on Test Set
#
# In this problem, you will take the best hyperparameter configuration you found in your earlier experiments (Randomized Search or Optuna) and fully evaluate the resulting model on the test set.
#
# **Background:**
# When performing hyperparameter tuning, we typically optimize for a single metric (e.g., F1). However, before deployment, it is essential to check **all relevant metrics** on the final test set to understand the model’s behavior in a balanced way.
#
# **Instructions:**
#
# 1. Take the best hyperparameters you found in Problems 2 or 3 and apply them to your `pipelined_model`.
# 2. Re-train this final tuned model on the **entire training set** (not just the folds).
# 3. Evaluate the final model on the heldout **test set**, reporting the following metrics:
#
#    * Precision
#    * Recall
#    * F1 score
#    * Balanced accuracy
# 4. Use `classification_report` **on the test set** to print precision, recall, and F1 score, and use `balanced_accuracy_score` separately to calculate and print balanced accuracy.
# 5. Answer the graded questions.
#
# **Note:** We evaluate the metrics on the test set because it was never seen during training or hyperparameter tuning. This gives us an unbiased estimate of how the model will perform on truly unseen data. Evaluating on the training set would be misleading, because the model has already learned from that data and could appear artificially good.

# %%
# Your code here

# Use best parameters from Optuna (Problem 3)
best_params = {
    "gb__learning_rate": 0.08905948282237294,
    "gb__max_leaf_nodes": 130,
    "gb__max_depth": 5,
    "gb__min_samples_leaf": 98,
    "gb__l2_regularization": 1.077887350272901
}

# Apply parameters to pipeline
final_model = pipelined_model.set_params(**best_params)

# Train on full training set
final_model.fit(X_train, y_train)

# Predict on test set
y_pred = final_model.predict(X_test)

# Classification report (precision, recall, F1)

print("Classification Report:\n")
print(classification_report(y_test, y_pred))

# Balanced accuracy
bal_acc = balanced_accuracy_score(y_test, y_pred)
print(f"Balanced Accuracy: {bal_acc:.4f}")
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.82      0.88      7431
#            1       0.61      0.87      0.71      2338
#
#     accuracy                           0.83      9769
#    macro avg       0.78      0.84      0.80      9769
# weighted avg       0.87      0.83      0.84      9769
#
# Balanced Accuracy: 0.8448

# %% [markdown]
# ### Problem 4 Graded Questions
#
# - Set `a4a` to the balanced accuracy score of the best model.
# - Set `a4b` to the macro average precision of this model.
# - Set `a4c` to the macro average recall score of the this model.
#
# **Note:** Macro average takes the mean of each class’s precision/recall without considering how many samples each class has, which is appropriate for a balanced evaluation.

# %%
 # Your answer here

a4a = bal_acc                     # replace 0 with your answer, use variable or expression from above

# %%
# DO NOT change this cell in any way

print(f'a4a = {a4a:.4f}')
# Out:
# a4a = 0.8448

# %%
 # Your answer here

a4b = 0.78                     # replace 0 with your answer, may copy from the displayed results

# %%
# DO NOT change this cell in any way

print(f'a4b = {a4b:.4f}')
# Out:
# a4b = 0.7800

# %%
 # Your answer here

a4c = 0.84                     # replace 0 with your answer, may copy from the displayed results

# %%
# DO NOT change this cell in any way

print(f'a4c = {a4c:.4f}')
# Out:
# a4c = 0.8400

# %% [markdown]
# ## Problem 5: Understanding Precision, Recall, F1, and Balanced Accuracy
#
# **Tutorial**
#
# In binary classification, you will often evaluate these key metrics:
#
# * **Precision**: *Of all the positive predictions the model made, how many were actually correct?*
#
#   * High precision = few false positives
#   * Low precision = many false positives
#
# * **Recall**: *Of all the actual positive cases, how many did the model correctly identify?*
#
#   * High recall = few false negatives
#   * Low recall = many false negatives
#
# * **F1 score**: The harmonic mean of precision and recall, which balances them in a single measure.
#
#   * F1 is **highest** when precision and recall are both high and similar in value.
#   * If precision and recall are unbalanced, F1 will drop to reflect that imbalance.
#
# * **Balanced accuracy**: The average of recall across both classes (positive and negative).
#
#   * It ensures the classifier is performing reasonably well on *both* groups, correcting for class imbalance.
#   * Balanced accuracy is especially important if the classes are very unequal in size.
#
# **Typical trade-offs to remember:**
#
# * **Higher recall, lower precision**: the model finds most true positives but also mislabels some negatives as positives
# * **Higher precision, lower recall**: the model is strict about positive predictions, but misses some true positives
# * **Balanced precision and recall (good F1)**: a practical compromise
# * **Balanced accuracy**: checks fairness across both classes

# %% [markdown]
# ###  Problem 5 Graded Question (multiple choice)
#
# A bank uses your model to identify customers earning over $50K for a premium product invitation. Based on your final test set evaluation, including macro-averaged precision and recall, which of the following best describes what might happen?
#
# (1) The bank will miss some eligible high-income customers, but will avoid marketing mistakes by sending invitations only to those it is  confident about.
#
# (2) The bank will successfully reach most high-income customers, but will also waste resources sending invitations to some low-income customers.
#
# (3) The bank will perfectly identify all high-income and low-income customers, resulting in no wasted invitations and no missed opportunities.

# %%
 # Your answer here

a5 = 2                     # replace 0 with one of 1, 2, or 3

# %%
# DO NOT change this cell in any way

print(f'a5 = {a5}')
# Out:
# a5 = 2

# %% [markdown]
# ### Appendix One: Feature Engineering
#
# Here are some practical feature-engineering tweaks worth considering (beyond simply ordinal-encoding the categoricals)
#
# | Feature(s)                                                           | Why the tweak can help                                                                                                                                                     | How to do it (quick version)                                                                                                                                                    | Keep / drop?      |
# | -------------------------------------------------------------------- | -------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------- |
# | **`fnlwgt`**                                                         | Survey sampling weight, not a predictor. Leaving it in often lets the model “cheat.”                                                                                       | `df = df.drop(columns=["fnlwgt"])`                                                                                                                                              | **Drop**          |
# | **`education` *vs.* `education-num`**                                | They encode the **same** information twice (categorical label and its ordinal rank). Keeping both is redundant and can cause leakage of a perfectly predictive feature.    | Usually keep **only one**. For tree models `education-num` is simplest: `df = df.drop(columns=["education"])`                                                                   | **Drop one**      |
# | **`capital-gain`, `capital-loss`**                                   | Highly skewed; most values are zero with a long upper tail. The sign (gain vs. loss) matters, but treating them separately wastes a feature slot.                          | 1) Combine: `df["capital_net"] = df["capital-gain"] - df["capital-loss"]`; 2) Log-transform to reduce skew: `df["capital_net_log"] = np.log1p(df["capital_net"].clip(lower=0))` | Replace originals |
# | **`age`, `hours-per-week`**                                          | Continuous but with natural plateaus—trees handle splits fine, yet log or square-root scaling can soften extreme values; bucketing makes partial-dependence plots clearer. | Simple bucket: `df["age_bin"] = pd.cut(df["age"], bins=[16,25,35,45,55,65,90])` (optional)                                                                                      | Optional          |
# | **Missing categories** (`workclass`, `occupation`, `native-country`) | HGB handles `-1`/`-2` codes fine, but you may want *explicit* “Missing” bucket for interpretability.                                                                       | Use `encoded_missing_value=-2` during encoding.                                                                                                            | Keep as is        |
# | **Rare categories in `native-country`**                              | Hundreds of low-frequency countries dilute signal; grouping boosts stability.                                                                                              | Map infrequent categories to “Other”:                                                                                                                                           |                   |
#
#
# #### Minimum set of tweaks (good baseline, low effort)
#
# 1. **Drop `fnlwgt`.**
# 2. **Keep `education-num`, drop `education`.**
# 3. **Combine `capital-gain` and `capital-loss` into `capital_net`** (optionally add a log-scaled version).
# 4. Leave other numeric/categorical features as is; your histogram-GBDT will cope.
